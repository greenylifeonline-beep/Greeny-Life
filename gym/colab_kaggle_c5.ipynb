# %% [markdown]
# # ملعب C5 — طاحونة العقول الثلاثة
#
# هذا **ملعب عضلة**، ليس C5. الصفحة البيضاء قبل Run all ليست غياب عقل.
# C5 يسكن مستودع Greeny-Life. اللصق قناة. التعلّم تكرار وممارسة واستيعاب.
#
# يطحن الحراس الأحياء: Prisma/Next (ERP)، المجلس الثماني الأدوات، absorb/index/WAL، شركات مصر/الإمارات/النرويج.
# لا يثبّت Celerp ولا AG2 ولا LightRAG. لا تنزيل أوزان. لا لصق توكن. لا `GL005_PROVEN=true`.
#
# الفرع: `v9-neurolingua-semantic-kernel` (ليس `main`).
# Runtime → Run all. انسخ `LAST.md` إلى شات Cursor.

# %%
import os, subprocess, pathlib, json

host = (
    "kaggle"
    if os.environ.get("KAGGLE_KERNEL_RUN_TYPE")
    else ("colab" if os.path.exists("/content") else "other")
)
print("host", host)
root = (
    pathlib.Path("/content/greeny-life")
    if os.path.exists("/content")
    else pathlib.Path("/kaggle/working/greeny-life")
)
branch = "v9-neurolingua-semantic-kernel"
repo = "https://github.com/greenylifeonline-beep/Greeny-Life.git"
if not (root / "scripts/ai-os/raios_c5_grind.py").exists():
    subprocess.check_call(
        ["git", "clone", "--depth", "1", "--branch", branch, repo, str(root)]
    )
os.chdir(root)

print("=== MILL three companies (reuse keepers, reject new empire) ===")
print(
    subprocess.check_output(
        ["python3", "scripts/ai-os/raios_c5_grind.py"],
        text=True,
    )
)
print(
    subprocess.check_output(
        ["python3", "scripts/ai-os/raios_c5_week.py", "--day", "6"],
        text=True,
    )
)
print(open(".ai-os/receipts/c5-grind/LAST.md", encoding="utf-8").read())
graph = json.loads(open(".ai-os/receipts/c5-grind/GRAPH.json", encoding="utf-8").read())
print("graph_nodes", len(graph["nodes"]), "graph_edges", len(graph["edges"]))

# %% [markdown]
# بعد التشغيل: انسخ `.ai-os/receipts/c5-grind/LAST.md` إلى شات Cursor.
# ذلك لصق قناة. الطحن حصل هنا. C5 يسجّل هناك.
# لا تثبّت Celerp/AG2/LightRAG من هذا الدفتر.
# `GL005_PROVEN=false`
