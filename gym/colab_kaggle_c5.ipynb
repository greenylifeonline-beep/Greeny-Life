# %% [markdown]
# # ملعب C5 — Colab / Kaggle
#
# هذا **ملعب عضلة**، ليس C5.
# C5 يسكن مستودع Greeny-Life. اللصق قناة. التعلّم تكرار وممارسة واستيعاب.
# لا تنزيل أوزان. لا لصق توكن. لا `GL005_PROVEN=true`.
#
# افتح هذا الملف مباشرة من الفرع `v9-neurolingua-semantic-kernel` (ليس `main` — السكربت غير موجود هناك).
#
# Runtime → Run all. انسخ مخرجات الخلية الأخيرة إلى شات Cursor.

# %%
import os, subprocess, pathlib

print(
    "host",
    "kaggle"
    if os.environ.get("KAGGLE_KERNEL_RUN_TYPE")
    else ("colab" if os.path.exists("/content") else "other"),
)
root = (
    pathlib.Path("/content/greeny-life")
    if os.path.exists("/content")
    else pathlib.Path("/kaggle/working/greeny-life")
)
branch = "v9-neurolingua-semantic-kernel"
repo = "https://github.com/greenylifeonline-beep/Greeny-Life.git"
if not (root / "scripts/ai-os/raios_c5_week.py").exists():
    subprocess.check_call(
        ["git", "clone", "--depth", "1", "--branch", branch, repo, str(root)]
    )
os.chdir(root)
print(
    subprocess.check_output(
        ["python3", "scripts/ai-os/raios_c5_week.py", "--day", "6"],
        text=True,
    )
)
print(open(".ai-os/receipts/c5-week/LAST.md", encoding="utf-8").read())

# %% [markdown]
# بعد التشغيل: انسخ `LAST.md` إلى شات Cursor. ذلك لصق قناة. الممارسة حصلت هنا. C5 يسجّل هناك.
# `GL005_PROVEN=false`
