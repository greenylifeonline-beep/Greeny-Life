# %% [markdown]
# # ملعب C5 — Colab / Kaggle
#
# هذا **ملعب عضلة**، ليس C5.
# C5 يسكن مستودع Greeny-Life. اللصق قناة. التعلّم تكرار وممارسة واستيعاب.
# لا تنزيل أوزان. لا إرسال أسرار. لا `GL005_PROVEN=true`.
#
# افتحه من: [Colab](https://colab.research.google.com/) أو [Kaggle Code](https://www.kaggle.com/code) بعد رفع الملف.

# %%
import os, subprocess, pathlib
print("host", "kaggle" if os.environ.get("KAGGLE_KERNEL_RUN_TYPE") else ("colab" if os.path.exists("/content") else "other"))
root = pathlib.Path("/content/greeny-life") if os.path.exists("/content") else pathlib.Path("/kaggle/working/greeny-life")
if not (root / "scripts/ai-os/raios_c5_week.py").exists():
    subprocess.check_call(["git", "clone", "--depth", "1", "https://github.com/greenylifeonline-beep/Greeny-Life.git", str(root)])
os.chdir(root)
print(subprocess.check_output(["python3", "scripts/ai-os/raios_c5_week.py", "--day", "6"], text=True))
print(open(".ai-os/receipts/c5-week/LAST.md", encoding="utf-8").read())

# %% [markdown]
# بعد التشغيل: انسخ `LAST.md` إلى شات Cursor. ذلك لصق قناة. الممارسة حصلت هنا. C5 يسجّل هناك.
# `GL005_PROVEN=false`
